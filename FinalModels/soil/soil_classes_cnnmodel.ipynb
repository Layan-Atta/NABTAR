# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# المكتبات
import os
import cv2
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
import re
import shutil

# %%
# Define the source dataset paths
dataset_path = "/content/drive/MyDrive/nbtar/data/soil_types_dataset"
train_source = os.path.join(dataset_path, "Train")
test_source = os.path.join(dataset_path, "test")

# Define the destination directory
new_dataset_path = "/content/dataset"

# Create new train and test directories in the new location
train_dest = os.path.join(new_dataset_path, "Train")
test_dest = os.path.join(new_dataset_path, "Test")

os.makedirs(train_dest, exist_ok=True)
os.makedirs(test_dest, exist_ok=True)
# Function to rename and move the images
def process_image(source_folder, destination_folder,image_counter=1):

    for soil in os.listdir(source_folder):
        soil_folder = os.path.join(source_folder, soil)
        new_soil_folder = os.path.join(destination_folder, soil)
        os.makedirs(new_soil_folder, exist_ok=True)

        if os.path.isdir(soil_folder):
            # Initialize a counter for numbering images

            for filename in os.listdir(soil_folder):
                old_path = os.path.join(soil_folder, filename)

                # Skip directories like .ipynb_checkpoints
                if os.path.isdir(old_path):
                    continue

                # Get the file extension
                _, ext = os.path.splitext(filename)
                if ext.lower() not in ['.jpg', '.jpeg', '.png']:  # Ensure the file is an image
                    continue

                # Rename the file with just numbers (1, 2, 3, ...)
                new_filename = f"{image_counter}{ext}"
                new_path = os.path.join(new_soil_folder, new_filename)

                # Rename & move the file
                shutil.copy2(old_path, new_path)
                print(f"Copied: {filename} -> {new_path}")

                # Increment the counter for the next image
                image_counter += 1
    return image_counter

# Process training images
image_counter=process_image(train_source, train_dest)

# Process testing images
process_image(test_source, test_dest,image_counter)

print(f" New dataset saved in: {new_dataset_path}")
# Out:
# Copied: 1000_F_233167094_JhQz9xvHtlN5UyT3zt748JiJolOSid7s.jpg -> /content/dataset/Train/Red soil/1.jpg
# Copied: 15kg-red-soil-500x500.png -> /content/dataset/Train/Red soil/2.png
# Copied: Copy of 61050549-red-soil-texture-background.png -> /content/dataset/Train/Red soil/3.png
# Copied: Copy of Sample6.30.jpg -> /content/dataset/Train/Red soil/4.jpg
# Copied: Copy of Sample6.60.jpg -> /content/dataset/Train/Red soil/5.jpg
# Copied: Copy of Sample8.120.jpg -> /content/dataset/Train/Red soil/6.jpg
# Copied: Copy of Sample6.180.jpg -> /content/dataset/Train/Red soil/7.jpg
# Copied: Copy of 61AysVsqgL.jpg -> /content/dataset/Train/Red soil/8.jpg
# Copied: Copy of Sample8.60.jpg -> /content/dataset/Train/Red soil/9.jpg
# Copied: Copy of 15kg-red-soil-500x500.png -> /content/dataset/Train/Red soil/10.png
# Copied: Copy of Sample6.90.jpg -> /content/dataset/Train/Red soil/11.jpg
# Copied: Copy of Sample6.150.jpg -> /content/dataset/Train/Red soil/12.jpg
# Copied: Copy of 51em0GmiApL._SX466_.jpg -> /content/dataset/Train/Red soil/13.jpg
# Copied: Copy of Sample6.120.jpg -> /content/dataset/Train/Red soil/14.jpg
# Copied: 250px-Ultisol.jpg -> /content/dataset/Train/Red soil/15.jpg
# Copied: Copy of 2560px-A_red_soil_crop_field.png -> /content/dataset/Train/Red soil/16.png
# Copied: Copy of 5-red-soil-topspot-original-imaftmfanswghcfr.jpeg -> /content/dataset/Train/Red soil/17.jpeg
# Copied: Copy of Sample8.0.jpg -> /content/dataset/Train/Red soil/18.jpg
# Copied: Copy of 5.jpg -> /content/dataset/Train/Red soil/19.jpg
# Copied: Copy of Sample8.180.jpg -> /content/dataset/Train/Red soil/20.jpg
# Copied: Copy of Sample6.0.jpg -> /content/dataset/Train/Red soil/21.jpg
# Copied: 3.jpg -> /content/dataset/Train/Red soil/22.jpg
# Copied: Copy of 3.jpg -> /content/dataset/Train/Red soil/23.jpg
# Copied: Copy of Sample8.30.jpg -> /content/dataset/Train/Red soil/24.jpg
# Copied: 51em0GmiApL._SX466_.jpg -> /content/dataset/Train/Red soil/25.jpg
# Copied: 95424d278d0b71fa4b398f406303a4a9.jpg -> /content/dataset/Train/Red soil/26.jpg
# Copied: 94530057-red-clay-soil-on-nature-as-a-background-.png -> /content/dataset/Train/Red soil/27.png
# Copied: Copy of 1000_F_233167094_JhQz9xvHtlN5UyT3zt748JiJolOSid7s.jpg -> /content/dataset/Train/Red soil/28.jpg
# Copied: 61AysVsqgL.jpg -> /content/dataset/Train/Red soil/29.jpg
# Copied: 5-red-soil-topspot-original-imaftmfanswghcfr.jpeg -> /content/dataset/Train/Red soil/30.jpeg
# Copied: Copy of Sample8.90.jpg -> /content/dataset/Train/Red soil/31.jpg
# Copied: 2560px-A_red_soil_crop_field.JPG -> /content/dataset/Train/Red soil/32.JPG
# Copied: Copy of Red-soil-essay.jpg -> /content/dataset/Train/Red soil/33.jpg
# Copied: 835254_2.jpg -> /content/dataset/Train/Red soil/34.jpg
# Copied: 5.jpg -> /content/dataset/Train/Red soil/35.jpg
# Copied: Copy of Sample8.150.jpg -> /content/dataset/Train/Red soil/36.jpg
# Copied: Copy of 835254_2.png -> /content/dataset/Train/Red soil/37.png
# Copied: Copy of 95424d278d0b71fa4b398f406303a4a9.jpg -> /content/dataset/Train/Red soil/38.jpg
# Copied: 61050549-red-soil-texture-background.png -> /content/dataset/Train/Red soil/39.png
# Copied: Copy of 250px-Ultisol.jpg -> /content/dataset/Train/Red soil/40.jpg
# Copied: Copy of Nc-red-clay-soil-2.jpg -> /content/dataset/Train/Red soil/41.jpg
# Copied: Copy of image14.jpeg -> /content/dataset/Train/Red soil/42.jpeg
# Copied: Copy of image24.jpeg -> /content/dataset/Train/Red soil/43.jpeg
# Copied: Copy of images131.jpg -> /content/dataset/Train/Red soil/44.jpg
# Copied: Copy of image.jpeg -> /content/dataset/Train/Red soil/45.jpeg
# Copied: Copy of images104.jpg -> /content/dataset/Train/Red soil/46.jpg
# Copied: Copy of images127.jpg -> /content/dataset/Train/Red soil/47.jpg
# Copied: Copy of image19.jpeg -> /content/dataset/Train/Red soil/48.jpeg
# Copied: Copy of images160.jpg -> /content/dataset/Train/Red soil/49.jpg
# Copied: Copy of images122.jpg -> /content/dataset/Train/Red soil/50.jpg
# Copied: Copy of images134.jpg -> /content/dataset/Train/Red soil/51.jpg
# Copied: Copy of images156.jpg -> /content/dataset/Train/Red soil/52.jpg
# Copied: Copy of download (1).jpg -> /content/dataset/Train/Red soil/53.jpg
# Copied: Copy of image-red-soil-texture-260nw-243951718.png -> /content/dataset/Train/Red soil/54.png
# Copied: Copy of images143.jpg -> /content/dataset/Train/Red soil/55.jpg
# Copied: Copy of image2.jpeg -> /content/dataset/Train/Red soil/56.jpeg
# Copied: Copy of brown-soil.jpg -> /content/dataset/Train/Red soil/57.jpg
# Copied: Copy of images102.jpg -> /content/dataset/Train/Red soil/58.jpg
# Copied: Copy of images125.png -> /content/dataset/Train/Red soil/59.png
# Copied: Copy of images152.jpg -> /content/dataset/Train/Red soil/60.jpg
# Copied: Copy of image12.jpeg -> /content/dataset/Train/Red soil/61.jpeg
# Copied: Copy of image17.jpeg -> /content/dataset/Train/Red soil/62.jpeg
# Copied: Copy of images137.jpg -> /content/dataset/Train/Red soil/63.jpg
# Copied: Copy of image8.jpeg -> /content/dataset/Train/Red soil/64.jpeg
# Copied: Copy of annamalai-red-soil-suppliers-kotturpuram-chennai-red-soil-dealers-ey0ylh5r3e.jpg -> /content/dataset/Train/Red soil/65.jpg
# Copied: Copy of images135.jpg -> /content/dataset/Train/Red soil/66.jpg
# Copied: Copy of download (2).png -> /content/dataset/Train/Red soil/67.png
# Copied: Copy of image20.jpeg -> /content/dataset/Train/Red soil/68.jpeg
# Copied: Copy of download.jpg -> /content/dataset/Train/Red soil/69.jpg
# Copied: Copy of image31.jpeg -> /content/dataset/Train/Red soil/70.jpeg
# Copied: Copy of images.jpg -> /content/dataset/Train/Red soil/71.jpg
# Copied: Copy of images113.jpg -> /content/dataset/Train/Red soil/72.jpg
# Copied: Copy of images10.jpg -> /content/dataset/Train/Red soil/73.jpg
# Copied: Copy of image15.jpeg -> /content/dataset/Train/Red soil/74.jpeg
# Copied: Copy of images13.jpg -> /content/dataset/Train/Red soil/75.jpg
# Copied: Copy of images (1).jpg -> /content/dataset/Train/Red soil/76.jpg
# Copied: Copy of image8.png -> /content/dataset/Train/Red soil/77.png
# Copied: Copy of image3.jpeg -> /content/dataset/Train/Red soil/78.jpeg
# Copied: Copy of images119.jpg -> /content/dataset/Train/Red soil/79.jpg
# Copied: Copy of images141.jpg -> /content/dataset/Train/Red soil/80.jpg
# Copied: Copy of image5.jpeg -> /content/dataset/Train/Red soil/81.jpeg
# Copied: Copy of images120.jpg -> /content/dataset/Train/Red soil/82.jpg
# Copied: Copy of images139.jpg -> /content/dataset/Train/Red soil/83.jpg
# Copied: Copy of images16.jpg -> /content/dataset/Train/Red soil/84.jpg
# Copied: Copy of image26.jpeg -> /content/dataset/Train/Red soil/85.jpeg
# Copied: Copy of image31.png -> /content/dataset/Train/Red soil/86.png
# Copied: Copy of images117.jpg -> /content/dataset/Train/Red soil/87.jpg
# Copied: Copy of image30.png -> /content/dataset/Train/Red soil/88.png
# Copied: Copy of images121.jpg -> /content/dataset/Train/Red soil/89.jpg
# Copied: Copy of images138.jpg -> /content/dataset/Train/Red soil/90.jpg
# Copied: Copy of image16.jpeg -> /content/dataset/Train/Red soil/91.jpeg
# Copied: Copy of image25.jpeg -> /content/dataset/Train/Red soil/92.jpeg
# Copied: Copy of image23.jpeg -> /content/dataset/Train/Red soil/93.jpeg
# Copied: Copy of images12.jpg -> /content/dataset/Train/Red soil/94.jpg
# Copied: Copy of images105.jpg -> /content/dataset/Train/Red soil/95.jpg
# Copied: Red_11.jpg -> /content/dataset/Train/Red soil/96.jpg
# Copied: Copy of images70.png -> /content/dataset/Train/Red soil/97.png
# Copied: Red_15.jpg -> /content/dataset/Train/Red soil/98.jpg
# Copied: Copy of red3.jpg -> /content/dataset/Train/Red soil/99.jpg
# Copied: Copy of red20clay-700x700.jpg -> /content/dataset/Train/Red soil/100.jpg
# Copied: Copy of images176.jpg -> /content/dataset/Train/Red soil/101.jpg
# Copied: Copy of images189.jpg -> /content/dataset/Train/Red soil/102.jpg
# Copied: Copy of images8.jpg -> /content/dataset/Train/Red soil/103.jpg
# Copied: Copy of red-ground-texture-260nw-1079913677.png -> /content/dataset/Train/Red soil/104.png
# Copied: Red_14.jpg -> /content/dataset/Train/Red soil/105.jpg
# Copied: Copy of images192.jpg -> /content/dataset/Train/Red soil/106.jpg
# Copied: Copy of images20.jpg -> /content/dataset/Train/Red soil/107.jpg
# Copied: Copy of images183.jpg -> /content/dataset/Train/Red soil/108.jpg
# Copied: Copy of red-soil-500x5002.jpg -> /content/dataset/Train/Red soil/109.jpg
# Copied: Copy of images45.jpg -> /content/dataset/Train/Red soil/110.jpg
# Copied: Copy of images202.jpg -> /content/dataset/Train/Red soil/111.jpg
# Copied: Copy of images36.jpg -> /content/dataset/Train/Red soil/112.jpg
# Copied: Copy of images6.jpg -> /content/dataset/Train/Red soil/113.jpg
# Copied: Copy of images43.jpg -> /content/dataset/Train/Red soil/114.jpg
# Copied: Copy of red-soil-500x5003.png -> /content/dataset/Train/Red soil/115.png
# Copied: Copy of images171.jpg -> /content/dataset/Train/Red soil/116.jpg
# Copied: Copy of red-soil-background-6402446.jpg -> /content/dataset/Train/Red soil/117.jpg
# Copied: Copy of images177.jpg -> /content/dataset/Train/Red soil/118.jpg
# Copied: Copy of images71.jpg -> /content/dataset/Train/Red soil/119.jpg
# Copied: Copy of images169.jpg -> /content/dataset/Train/Red soil/120.jpg
# Copied: Copy of utkl.jpg -> /content/dataset/Train/Red soil/121.jpg
# Copied: Red_10.jpg -> /content/dataset/Train/Red soil/122.jpg
# Copied: Red_12.jpg -> /content/dataset/Train/Red soil/123.jpg
# Copied: Red_16.jpg -> /content/dataset/Train/Red soil/124.jpg
# Copied: Copy of images68.jpg -> /content/dataset/Train/Red soil/125.jpg
# Copied: Copy of images195.jpg -> /content/dataset/Train/Red soil/126.jpg
# Copied: Copy of images188.jpg -> /content/dataset/Train/Red soil/127.jpg
# Copied: Copy of images77.jpg -> /content/dataset/Train/Red soil/128.jpg
# Copied: Copy of images191.jpg -> /content/dataset/Train/Red soil/129.jpg
# Copied: Copy of images46.jpg -> /content/dataset/Train/Red soil/130.jpg
# Copied: Copy of images162.jpg -> /content/dataset/Train/Red soil/131.jpg
# Copied: Copy of images95.jpg -> /content/dataset/Train/Red soil/132.jpg
# Copied: Red_13.jpg -> /content/dataset/Train/Red soil/133.jpg
# Copied: Red-soil-essay.jpg -> /content/dataset/Train/Red soil/134.jpg
# Copied: Copy of images165.jpg -> /content/dataset/Train/Red soil/135.jpg
# Copied: Copy of images96.jpg -> /content/dataset/Train/Red soil/136.jpg
# Copied: Copy of images168.jpg -> /content/dataset/Train/Red soil/137.jpg
# Copied: Red_1.jpg -> /content/dataset/Train/Red soil/138.jpg
# Copied: Nc-red-clay-soil-2.jpg -> /content/dataset/Train/Red soil/139.jpg
# Copied: Copy of images59.jpg -> /content/dataset/Train/Red soil/140.jpg
# Copied: Copy of red-soil-1.png -> /content/dataset/Train/Red soil/141.png
# Copied: Copy of images66.jpg -> /content/dataset/Train/Red soil/142.jpg
# Copied: Copy of images37.jpg -> /content/dataset/Train/Red soil/143.jpg
# Copied: Copy of images78.jpg -> /content/dataset/Train/Red soil/144.jpg
# Copied: Copy of images9.jpg -> /content/dataset/Train/Red soil/145.jpg
# Copied: Copy of images19.jpg -> /content/dataset/Train/Red soil/146.jpg
# Copied: Red_3.jpg -> /content/dataset/Train/Red soil/147.jpg
# Copied: Red_28.jpg -> /content/dataset/Train/Red soil/148.jpg
# Copied: Red_30.jpg -> /content/dataset/Train/Red soil/149.jpg
# Copied: Sample6.120.jpg -> /content/dataset/Train/Red soil/150.jpg
# Copied: Red_44.jpg -> /content/dataset/Train/Red soil/151.jpg
# Copied: Sample6.180.jpg -> /content/dataset/Train/Red soil/152.jpg
# Copied: Red_36.jpg -> /content/dataset/Train/Red soil/153.jpg
# Copied: image.jpeg -> /content/dataset/Train/Red soil/154.jpeg
# Copied: Red_37.jpg -> /content/dataset/Train/Red soil/155.jpg
# Copied: Red_38.jpg -> /content/dataset/Train/Red soil/156.jpg
# Copied: Red_20.jpg -> /content/dataset/Train/Red soil/157.jpg
# Copied: Red_2.jpg -> /content/dataset/Train/Red soil/158.jpg
# Copied: Red_42.jpg -> /content/dataset/Train/Red soil/159.jpg
# Copied: image12.jpeg -> /content/dataset/Train/Red soil/160.jpeg
# Copied: Sample6.60.jpg -> /content/dataset/Train/Red soil/161.jpg
# Copied: Red_24.jpg -> /content/dataset/Train/Red soil/162.jpg
# Copied: Sample6.150.jpg -> /content/dataset/Train/Red soil/163.jpg
# Copied: annamalai-red-soil-suppliers-kotturpuram-chennai-red-soil-dealers-ey0ylh5r3e.jpg -> /content/dataset/Train/Red soil/164.jpg
# Copied: Sample8.150.jpg -> /content/dataset/Train/Red soil/165.jpg
# Copied: Red_39.jpg -> /content/dataset/Train/Red soil/166.jpg
# Copied: Sample6.30.jpg -> /content/dataset/Train/Red soil/167.jpg
# Copied: Red_18.jpg -> /content/dataset/Train/Red soil/168.jpg
# Copied: Sample8.120.jpg -> /content/dataset/Train/Red soil/169.jpg
# Copied: Sample6.90.jpg -> /content/dataset/Train/Red soil/170.jpg
# Copied: Red_40.jpg -> /content/dataset/Train/Red soil/171.jpg
# Copied: Red_31.jpg -> /content/dataset/Train/Red soil/172.jpg
# Copied: Sample6.0.jpg -> /content/dataset/Train/Red soil/173.jpg
# Copied: Red_29.jpg -> /content/dataset/Train/Red soil/174.jpg
# Copied: image14.jpeg -> /content/dataset/Train/Red soil/175.jpeg
# Copied: Sample8.30.jpg -> /content/dataset/Train/Red soil/176.jpg
# Copied: Red_19.jpg -> /content/dataset/Train/Red soil/177.jpg
# Copied: Red_21.jpg -> /content/dataset/Train/Red soil/178.jpg
# Copied: Red_22.jpg -> /content/dataset/Train/Red soil/179.jpg
# Copied: Red_46.jpg -> /content/dataset/Train/Red soil/180.jpg
# Copied: Red_43.jpg -> /content/dataset/Train/Red soil/181.jpg
# Copied: Sample8.60.jpg -> /content/dataset/Train/Red soil/182.jpg
# Copied: Red_5.jpg -> /content/dataset/Train/Red soil/183.jpg
# Copied: Red_8.jpg -> /content/dataset/Train/Red soil/184.jpg
# Copied: image-red-soil-texture-260nw-243951718.png -> /content/dataset/Train/Red soil/185.png
# Copied: Red_17.jpg -> /content/dataset/Train/Red soil/186.jpg
# Copied: brown-soil.jpg -> /content/dataset/Train/Red soil/187.jpg
# Copied: Red_7.jpg -> /content/dataset/Train/Red soil/188.jpg
# Copied: Red_41.jpg -> /content/dataset/Train/Red soil/189.jpg
# Copied: Sample8.0.jpg -> /content/dataset/Train/Red soil/190.jpg
# Copied: Red_6.jpg -> /content/dataset/Train/Red soil/191.jpg
# Copied: Red_23.jpg -> /content/dataset/Train/Red soil/192.jpg
# Copied: Red_4.jpg -> /content/dataset/Train/Red soil/193.jpg
# Copied: Red_35.jpg -> /content/dataset/Train/Red soil/194.jpg
# Copied: Sample8.180.jpg -> /content/dataset/Train/Red soil/195.jpg
# Copied: Red_9.jpg -> /content/dataset/Train/Red soil/196.jpg
# Copied: Sample8.90.jpg -> /content/dataset/Train/Red soil/197.jpg
# Copied: Red_45.jpg -> /content/dataset/Train/Red soil/198.jpg
# Copied: Red_27.jpg -> /content/dataset/Train/Red soil/199.jpg
# Copied: Red_32.jpg -> /content/dataset/Train/Red soil/200.jpg
# Copied: images19.jpg -> /content/dataset/Train/Red soil/201.jpg
# Copied: images139.jpg -> /content/dataset/Train/Red soil/202.jpg
# Copied: images156.jpg -> /content/dataset/Train/Red soil/203.jpg
# Copied: images77.jpg -> /content/dataset/Train/Red soil/204.jpg
# Copied: images37.jpg -> /content/dataset/Train/Red soil/205.jpg
# Copied: images121.jpg -> /content/dataset/Train/Red soil/206.jpg
# Copied: images137.jpg -> /content/dataset/Train/Red soil/207.jpg
# Copied: images45.jpg -> /content/dataset/Train/Red soil/208.jpg
# Copied: images68.jpg -> /content/dataset/Train/Red soil/209.jpg
# Copied: images138.jpg -> /content/dataset/Train/Red soil/210.jpg
# Copied: images10.jpg -> /content/dataset/Train/Red soil/211.jpg
# Copied: image31.jpeg -> /content/dataset/Train/Red soil/212.jpeg
# Copied: images176.jpg -> /content/dataset/Train/Red soil/213.jpg
# Copied: images134.jpg -> /content/dataset/Train/Red soil/214.jpg
# Copied: image16.jpeg -> /content/dataset/Train/Red soil/215.jpeg
# Copied: images171.jpg -> /content/dataset/Train/Red soil/216.jpg
# Copied: image30.jpeg -> /content/dataset/Train/Red soil/217.jpeg
# Copied: images127.jpg -> /content/dataset/Train/Red soil/218.jpg
# Copied: images66.jpg -> /content/dataset/Train/Red soil/219.jpg
# Copied: images71.jpg -> /content/dataset/Train/Red soil/220.jpg
# Copied: images160.jpg -> /content/dataset/Train/Red soil/221.jpg
# Copied: image8.jpeg -> /content/dataset/Train/Red soil/222.jpeg
# Copied: images143.jpg -> /content/dataset/Train/Red soil/223.jpg
# Copied: images6.jpg -> /content/dataset/Train/Red soil/224.jpg
# Copied: images13.jpg -> /content/dataset/Train/Red soil/225.jpg
# Copied: image3.jpeg -> /content/dataset/Train/Red soil/226.jpeg
# Copied: image26.jpeg -> /content/dataset/Train/Red soil/227.jpeg
# Copied: images195.jpg -> /content/dataset/Train/Red soil/228.jpg
# Copied: images202.jpg -> /content/dataset/Train/Red soil/229.jpg
# Copied: images59.jpg -> /content/dataset/Train/Red soil/230.jpg
# Copied: image20.jpeg -> /content/dataset/Train/Red soil/231.jpeg
# Copied: images12.jpg -> /content/dataset/Train/Red soil/232.jpg
# Copied: images36.jpg -> /content/dataset/Train/Red soil/233.jpg
# Copied: images162.jpg -> /content/dataset/Train/Red soil/234.jpg
# Copied: image17.jpeg -> /content/dataset/Train/Red soil/235.jpeg
# Copied: images165.jpg -> /content/dataset/Train/Red soil/236.jpg
# Copied: images192.jpg -> /content/dataset/Train/Red soil/237.jpg
# Copied: images189.jpg -> /content/dataset/Train/Red soil/238.jpg
# Copied: images177.jpg -> /content/dataset/Train/Red soil/239.jpg
# Copied: images169.jpg -> /content/dataset/Train/Red soil/240.jpg
# Copied: image24.jpeg -> /content/dataset/Train/Red soil/241.jpeg
# Copied: images16.jpg -> /content/dataset/Train/Red soil/242.jpg
# Copied: images152.jpg -> /content/dataset/Train/Red soil/243.jpg
# Copied: images168.jpg -> /content/dataset/Train/Red soil/244.jpg
# Copied: image2.jpeg -> /content/dataset/Train/Red soil/245.jpeg
# Copied: image5.jpeg -> /content/dataset/Train/Red soil/246.jpeg
# Copied: images70.jpg -> /content/dataset/Train/Red soil/247.jpg
# Copied: image15.jpeg -> /content/dataset/Train/Red soil/248.jpeg
# Copied: images188.jpg -> /content/dataset/Train/Red soil/249.jpg
# Copied: images191.jpg -> /content/dataset/Train/Red soil/250.jpg
# Copied: images46.jpg -> /content/dataset/Train/Red soil/251.jpg
# Copied: image19.jpeg -> /content/dataset/Train/Red soil/252.jpeg
# Copied: image23.jpeg -> /content/dataset/Train/Red soil/253.jpeg
# Copied: images20.jpg -> /content/dataset/Train/Red soil/254.jpg
# Copied: images183.jpg -> /content/dataset/Train/Red soil/255.jpg
# Copied: image25.jpeg -> /content/dataset/Train/Red soil/256.jpeg
# Copied: images9.jpg -> /content/dataset/Train/Red soil/257.jpg
# Copied: red-soil-1.png -> /content/dataset/Train/Red soil/258.png
# Copied: images8.jpg -> /content/dataset/Train/Red soil/259.jpg
# Copied: utkl.jpg -> /content/dataset/Train/Red soil/260.jpg
# Copied: red-ground-texture-260nw-1079913677.png -> /content/dataset/Train/Red soil/261.png
# Copied: red20clay-700x700.jpg -> /content/dataset/Train/Red soil/262.jpg
# Copied: red-soil-500x5002.jpg -> /content/dataset/Train/Red soil/263.jpg
# Copied: red-soil-500x5003.png -> /content/dataset/Train/Red soil/264.png
# Copied: red-soil-background-6402446.jpg -> /content/dataset/Train/Red soil/265.jpg
# Copied: red3.jpg -> /content/dataset/Train/Red soil/266.jpg
# Copied: images78.jpg -> /content/dataset/Train/Red soil/267.jpg
# Copied: Black_10.jpg -> /content/dataset/Train/Black Soil/268.jpg
# Copied: Black_11.jpg -> /content/dataset/Train/Black Soil/269.jpg
# Copied: Black_47.jpg -> /content/dataset/Train/Black Soil/270.jpg
# Copied: Black_31.jpg -> /content/dataset/Train/Black Soil/271.jpg
# Copied: Black_2.jpg -> /content/dataset/Train/Black Soil/272.jpg
# Copied: Black_9.jpg -> /content/dataset/Train/Black Soil/273.jpg
# Copied: Black_15.jpg -> /content/dataset/Train/Black Soil/274.jpg
# Copied: Black_22.jpg -> /content/dataset/Train/Black Soil/275.jpg
# Copied: Black_45.jpg -> /content/dataset/Train/Black Soil/276.jpg
# Copied: Black_6.jpg -> /content/dataset/Train/Black Soil/277.jpg
# Copied: Black_37.jpg -> /content/dataset/Train/Black Soil/278.jpg
# Copied: Black_26.jpg -> /content/dataset/Train/Black Soil/279.jpg
# Copied: Black_34.jpg -> /content/dataset/Train/Black Soil/280.jpg
# Copied: Copy of Copy of images436.jpg -> /content/dataset/Train/Black Soil/281.jpg
# Copied: Black_44.jpg -> /content/dataset/Train/Black Soil/282.jpg
# Copied: Black_42.jpg -> /content/dataset/Train/Black Soil/283.jpg
# Copied: Black_25.jpg -> /content/dataset/Train/Black Soil/284.jpg
# Copied: Black_14.jpg -> /content/dataset/Train/Black Soil/285.jpg
# Copied: Black_8.jpg -> /content/dataset/Train/Black Soil/286.jpg
# Copied: Black_46.jpg -> /content/dataset/Train/Black Soil/287.jpg
# Copied: Black_12.jpg -> /content/dataset/Train/Black Soil/288.jpg
# Copied: Black_33.jpg -> /content/dataset/Train/Black Soil/289.jpg
# Copied: Black_24.jpg -> /content/dataset/Train/Black Soil/290.jpg
# Copied: Black_36.jpg -> /content/dataset/Train/Black Soil/291.jpg
# Copied: Black_28.jpg -> /content/dataset/Train/Black Soil/292.jpg
# Copied: Black_41.jpg -> /content/dataset/Train/Black Soil/293.jpg
# Copied: Black_39.jpg -> /content/dataset/Train/Black Soil/294.jpg
# Copied: Copy of Copy of images435(1).jpg -> /content/dataset/Train/Black Soil/295.jpg
# Copied: Black_35.jpg -> /content/dataset/Train/Black Soil/296.jpg
# Copied: Black_23.jpg -> /content/dataset/Train/Black Soil/297.jpg
# Copied: Black_13.jpg -> /content/dataset/Train/Black Soil/298.jpg
# Copied: Copy of Copy of images437(1).jpg -> /content/dataset/Train/Black Soil/299.jpg
# Copied: Black_18.jpg -> /content/dataset/Train/Black Soil/300.jpg
# Copied: Black_29.jpg -> /content/dataset/Train/Black Soil/301.jpg
# Copied: Copy of Copy of images434.jpg -> /content/dataset/Train/Black Soil/302.jpg
# Copied: Copy of Copy of Sample7.0.jpg -> /content/dataset/Train/Black Soil/303.jpg
# Copied: Black_32.jpg -> /content/dataset/Train/Black Soil/304.jpg
# Copied: Black_3.jpg -> /content/dataset/Train/Black Soil/305.jpg
# Copied: Black_21.jpg -> /content/dataset/Train/Black Soil/306.jpg
# Copied: Copy of Copy of images435.jpg -> /content/dataset/Train/Black Soil/307.jpg
# Copied: Black_5.jpg -> /content/dataset/Train/Black Soil/308.jpg
# Copied: Black_20.jpg -> /content/dataset/Train/Black Soil/309.jpg
# Copied: Black_17.jpg -> /content/dataset/Train/Black Soil/310.jpg
# Copied: Copy of Copy of images436(1).jpg -> /content/dataset/Train/Black Soil/311.jpg
# Copied: Black_19.jpg -> /content/dataset/Train/Black Soil/312.jpg
# Copied: Black_16.jpg -> /content/dataset/Train/Black Soil/313.jpg
# Copied: Black_4.jpg -> /content/dataset/Train/Black Soil/314.jpg
# Copied: Black_40.jpg -> /content/dataset/Train/Black Soil/315.jpg
# Copied: Black_30.jpg -> /content/dataset/Train/Black Soil/316.jpg
# Copied: Black_38.jpg -> /content/dataset/Train/Black Soil/317.jpg
# Copied: Copy of Copy of Sample7.30.jpg -> /content/dataset/Train/Black Soil/318.jpg
# Copied: Black_27.jpg -> /content/dataset/Train/Black Soil/319.jpg
# Copied: Black_1.jpg -> /content/dataset/Train/Black Soil/320.jpg
# Copied: Black_43.jpg -> /content/dataset/Train/Black Soil/321.jpg
# Copied: Black_7.jpg -> /content/dataset/Train/Black Soil/322.jpg
# Copied: Copy of images318.jpg -> /content/dataset/Train/Black Soil/323.jpg
# Copied: Copy of images298.jpg -> /content/dataset/Train/Black Soil/324.jpg
# Copied: Copy of images371(1).jpg -> /content/dataset/Train/Black Soil/325.jpg
# Copied: Copy of Sample7.0.jpg -> /content/dataset/Train/Black Soil/326.jpg
# Copied: Copy of images281(1).jpg -> /content/dataset/Train/Black Soil/327.jpg
# Copied: Copy of images337(1).jpg -> /content/dataset/Train/Black Soil/328.jpg
# Copied: Copy of images390.jpg -> /content/dataset/Train/Black Soil/329.jpg
# Copied: Copy of images390(1).jpg -> /content/dataset/Train/Black Soil/330.jpg
# Copied: Copy of images337.jpg -> /content/dataset/Train/Black Soil/331.jpg
# Copied: Copy of images365.jpg -> /content/dataset/Train/Black Soil/332.jpg
# Copied: Copy of images284.jpg -> /content/dataset/Train/Black Soil/333.jpg
# Copied: Copy of images391.jpg -> /content/dataset/Train/Black Soil/334.jpg
# Copied: Copy of images258(1).jpg -> /content/dataset/Train/Black Soil/335.jpg
# Copied: Copy of images318(1).jpg -> /content/dataset/Train/Black Soil/336.jpg
# Copied: Copy of images287(1).jpg -> /content/dataset/Train/Black Soil/337.jpg
# Copied: Copy of Sample7.30.jpg -> /content/dataset/Train/Black Soil/338.jpg
# Copied: Copy of images375.jpg -> /content/dataset/Train/Black Soil/339.jpg
# Copied: Copy of Copy of images437.jpg -> /content/dataset/Train/Black Soil/340.jpg
# Copied: Copy of images258.jpg -> /content/dataset/Train/Black Soil/341.jpg
# Copied: Copy of images281.jpg -> /content/dataset/Train/Black Soil/342.jpg
# Copied: Copy of images392(1).jpg -> /content/dataset/Train/Black Soil/343.jpg
# Copied: Copy of images363(1).jpg -> /content/dataset/Train/Black Soil/344.jpg
# Copied: Copy of images363.jpg -> /content/dataset/Train/Black Soil/345.jpg
# Copied: Copy of images274.jpg -> /content/dataset/Train/Black Soil/346.jpg
# Copied: Copy of images284(1).jpg -> /content/dataset/Train/Black Soil/347.jpg
# Copied: Copy of images392.jpg -> /content/dataset/Train/Black Soil/348.jpg
# Copied: Copy of Copy of kalimitti2.jpg -> /content/dataset/Train/Black Soil/349.jpg
# Copied: Copy of images375(1).jpg -> /content/dataset/Train/Black Soil/350.jpg
# Copied: Copy of image27.jpeg -> /content/dataset/Train/Black Soil/351.jpeg
# Copied: Copy of images350.jpg -> /content/dataset/Train/Black Soil/352.jpg
# Copied: Copy of images267(1).jpg -> /content/dataset/Train/Black Soil/353.jpg
# Copied: Copy of images347.jpg -> /content/dataset/Train/Black Soil/354.jpg
# Copied: Copy of images386.jpg -> /content/dataset/Train/Black Soil/355.jpg
# Copied: Copy of images287.jpg -> /content/dataset/Train/Black Soil/356.jpg
# Copied: Copy of images267.jpg -> /content/dataset/Train/Black Soil/357.jpg
# Copied: Copy of images280(1).jpg -> /content/dataset/Train/Black Soil/358.jpg
# Copied: Copy of images305.jpg -> /content/dataset/Train/Black Soil/359.jpg
# Copied: Copy of images298(1).jpg -> /content/dataset/Train/Black Soil/360.jpg
# Copied: Copy of image27(1).jpeg -> /content/dataset/Train/Black Soil/361.jpeg
# Copied: Copy of images393(1).jpg -> /content/dataset/Train/Black Soil/362.jpg
# Copied: Copy of Sample4.30.jpg -> /content/dataset/Train/Black Soil/363.jpg
# Copied: Copy of images271(1).jpg -> /content/dataset/Train/Black Soil/364.jpg
# Copied: Copy of images271.jpg -> /content/dataset/Train/Black Soil/365.jpg
# Copied: Copy of Copy of indian-soils-6.jpg -> /content/dataset/Train/Black Soil/366.jpg
# Copied: Copy of images274(1).jpg -> /content/dataset/Train/Black Soil/367.jpg
# Copied: Copy of images305(1).jpg -> /content/dataset/Train/Black Soil/368.jpg
# Copied: Copy of images359.jpg -> /content/dataset/Train/Black Soil/369.jpg
# Copied: Copy of images280.jpg -> /content/dataset/Train/Black Soil/370.jpg
# Copied: Copy of images347(1).jpg -> /content/dataset/Train/Black Soil/371.jpg
# Copied: Copy of images391(1).jpg -> /content/dataset/Train/Black Soil/372.jpg
# Copied: Copy of images393.jpg -> /content/dataset/Train/Black Soil/373.jpg
# Copied: Copy of images359(1).jpg -> /content/dataset/Train/Black Soil/374.jpg
# Copied: Copy of images350(1).jpg -> /content/dataset/Train/Black Soil/375.jpg
# Copied: Copy of images371.jpg -> /content/dataset/Train/Black Soil/376.jpg
# Copied: Copy of images365(1).jpg -> /content/dataset/Train/Black Soil/377.jpg
# Copied: Copy of images416.jpg -> /content/dataset/Train/Black Soil/378.jpg
# Copied: Copy of images421(1).jpg -> /content/dataset/Train/Black Soil/379.jpg
# Copied: Copy of images396.jpg -> /content/dataset/Train/Black Soil/380.jpg
# Copied: Copy of images404.jpg -> /content/dataset/Train/Black Soil/381.jpg
# Copied: Copy of images422.jpg -> /content/dataset/Train/Black Soil/382.jpg
# Copied: Copy of images425.jpg -> /content/dataset/Train/Black Soil/383.jpg
# Copied: Copy of images418.jpg -> /content/dataset/Train/Black Soil/384.jpg
# Copied: Copy of images427(1).jpg -> /content/dataset/Train/Black Soil/385.jpg
# Copied: Copy of images394(1).jpg -> /content/dataset/Train/Black Soil/386.jpg
# Copied: Copy of images417.jpg -> /content/dataset/Train/Black Soil/387.jpg
# Copied: Copy of images408(1).jpg -> /content/dataset/Train/Black Soil/388.jpg
# Copied: Copy of images395.jpg -> /content/dataset/Train/Black Soil/389.jpg
# Copied: Copy of images420(1).jpg -> /content/dataset/Train/Black Soil/390.jpg
# Copied: Copy of images410.jpg -> /content/dataset/Train/Black Soil/391.jpg
# Copied: Copy of images419(1).jpg -> /content/dataset/Train/Black Soil/392.jpg
# Copied: Copy of images421.jpg -> /content/dataset/Train/Black Soil/393.jpg
# Copied: Copy of images417(1).jpg -> /content/dataset/Train/Black Soil/394.jpg
# Copied: Copy of images428(1).jpg -> /content/dataset/Train/Black Soil/395.jpg
# Copied: Copy of images427.jpg -> /content/dataset/Train/Black Soil/396.jpg
# Copied: Copy of images401.jpg -> /content/dataset/Train/Black Soil/397.jpg
# Copied: Copy of images415.jpg -> /content/dataset/Train/Black Soil/398.jpg
# Copied: Copy of images405.jpg -> /content/dataset/Train/Black Soil/399.jpg
# Copied: Copy of images428.jpg -> /content/dataset/Train/Black Soil/400.jpg
# Copied: Copy of images399.jpg -> /content/dataset/Train/Black Soil/401.jpg
# Copied: Copy of images418(1).jpg -> /content/dataset/Train/Black Soil/402.jpg
# Copied: Copy of images394.jpg -> /content/dataset/Train/Black Soil/403.jpg
# Copied: Copy of images398.jpg -> /content/dataset/Train/Black Soil/404.jpg
# Copied: Copy of images397.jpg -> /content/dataset/Train/Black Soil/405.jpg
# Copied: Copy of images424.jpg -> /content/dataset/Train/Black Soil/406.jpg
# Copied: Copy of images415(1).jpg -> /content/dataset/Train/Black Soil/407.jpg
# Copied: Copy of images420.jpg -> /content/dataset/Train/Black Soil/408.jpg
# Copied: Copy of images398(1).jpg -> /content/dataset/Train/Black Soil/409.jpg
# Copied: Copy of images416(1).jpg -> /content/dataset/Train/Black Soil/410.jpg
# Copied: Copy of images424(1).jpg -> /content/dataset/Train/Black Soil/411.jpg
# Copied: Copy of images406.jpg -> /content/dataset/Train/Black Soil/412.jpg
# Copied: Copy of images400.jpg -> /content/dataset/Train/Black Soil/413.jpg
# Copied: Copy of images419.jpg -> /content/dataset/Train/Black Soil/414.jpg
# Copied: Copy of images423(1).jpg -> /content/dataset/Train/Black Soil/415.jpg
# Copied: Copy of images423.jpg -> /content/dataset/Train/Black Soil/416.jpg
# Copied: Copy of images413.jpg -> /content/dataset/Train/Black Soil/417.jpg
# Copied: Copy of images409.jpg -> /content/dataset/Train/Black Soil/418.jpg
# Copied: Copy of images425(1).jpg -> /content/dataset/Train/Black Soil/419.jpg
# Copied: Copy of images413(1).jpg -> /content/dataset/Train/Black Soil/420.jpg
# Copied: Copy of images409(1).jpg -> /content/dataset/Train/Black Soil/421.jpg
# Copied: Copy of images396(1).jpg -> /content/dataset/Train/Black Soil/422.jpg
# Copied: Copy of images422(1).jpg -> /content/dataset/Train/Black Soil/423.jpg
# Copied: Copy of images406(1).jpg -> /content/dataset/Train/Black Soil/424.jpg
# Copied: Copy of images410(1).jpg -> /content/dataset/Train/Black Soil/425.jpg
# Copied: Copy of images414(1).jpg -> /content/dataset/Train/Black Soil/426.jpg
# Copied: Copy of images408.jpg -> /content/dataset/Train/Black Soil/427.jpg
# Copied: Copy of images414.jpg -> /content/dataset/Train/Black Soil/428.jpg
# Copied: Copy of images395(1).jpg -> /content/dataset/Train/Black Soil/429.jpg
# Copied: Copy of images405(1).jpg -> /content/dataset/Train/Black Soil/430.jpg
# Copied: Copy of images403.jpg -> /content/dataset/Train/Black Soil/431.jpg
# Copied: Copy of images397(1).jpg -> /content/dataset/Train/Black Soil/432.jpg
# Copied: images396.jpg -> /content/dataset/Train/Black Soil/433.jpg
# Copied: Copy of images435(1).jpg -> /content/dataset/Train/Black Soil/434.jpg
# Copied: Copy of images436(1).jpg -> /content/dataset/Train/Black Soil/435.jpg
# Copied: images393.jpg -> /content/dataset/Train/Black Soil/436.jpg
# Copied: Sample7.120.jpg -> /content/dataset/Train/Black Soil/437.jpg
# Copied: Sample7.150.jpg -> /content/dataset/Train/Black Soil/438.jpg
# Copied: images399.jpg -> /content/dataset/Train/Black Soil/439.jpg
# Copied: Copy of images430.jpg -> /content/dataset/Train/Black Soil/440.jpg
# Copied: images305.jpg -> /content/dataset/Train/Black Soil/441.jpg
# Copied: images298.jpg -> /content/dataset/Train/Black Soil/442.jpg
# Copied: images375.jpg -> /content/dataset/Train/Black Soil/443.jpg
# Copied: images258.jpg -> /content/dataset/Train/Black Soil/444.jpg
# Copied: Sample7.30.jpg -> /content/dataset/Train/Black Soil/445.jpg
# Copied: Copy of images432(1).jpg -> /content/dataset/Train/Black Soil/446.jpg
# Copied: images280.jpg -> /content/dataset/Train/Black Soil/447.jpg
# Copied: Copy of images436.jpg -> /content/dataset/Train/Black Soil/448.jpg
# Copied: images392.jpg -> /content/dataset/Train/Black Soil/449.jpg
# Copied: images359.jpg -> /content/dataset/Train/Black Soil/450.jpg
# Copied: images386.jpg -> /content/dataset/Train/Black Soil/451.jpg
# Copied: images318.jpg -> /content/dataset/Train/Black Soil/452.jpg
# Copied: Sample7.60.jpg -> /content/dataset/Train/Black Soil/453.jpg
# Copied: Copy of images434.jpg -> /content/dataset/Train/Black Soil/454.jpg
# Copied: Copy of images433.jpg -> /content/dataset/Train/Black Soil/455.jpg
# Copied: Copy of images432.jpg -> /content/dataset/Train/Black Soil/456.jpg
# Copied: images398.jpg -> /content/dataset/Train/Black Soil/457.jpg
# Copied: images401.jpg -> /content/dataset/Train/Black Soil/458.jpg
# Copied: Copy of images437.jpg -> /content/dataset/Train/Black Soil/459.jpg
# Copied: images287.jpg -> /content/dataset/Train/Black Soil/460.jpg
# Copied: Copy of images437(1).jpg -> /content/dataset/Train/Black Soil/461.jpg
# Copied: Copy of images429.jpg -> /content/dataset/Train/Black Soil/462.jpg
# Copied: Copy of indian-soils-6.jpg -> /content/dataset/Train/Black Soil/463.jpg
# Copied: images403.jpg -> /content/dataset/Train/Black Soil/464.jpg
# Copied: images337.jpg -> /content/dataset/Train/Black Soil/465.jpg
# Copied: Sample7.180.jpg -> /content/dataset/Train/Black Soil/466.jpg
# Copied: Sample4.30.jpg -> /content/dataset/Train/Black Soil/467.jpg
# Copied: images281.jpg -> /content/dataset/Train/Black Soil/468.jpg
# Copied: Copy of images429(1).jpg -> /content/dataset/Train/Black Soil/469.jpg
# Copied: images391.jpg -> /content/dataset/Train/Black Soil/470.jpg
# Copied: image27.jpeg -> /content/dataset/Train/Black Soil/471.jpeg
# Copied: images400.jpg -> /content/dataset/Train/Black Soil/472.jpg
# Copied: images395.jpg -> /content/dataset/Train/Black Soil/473.jpg
# Copied: Copy of kalimitti2.jpg -> /content/dataset/Train/Black Soil/474.jpg
# Copied: Copy of images431.jpg -> /content/dataset/Train/Black Soil/475.jpg
# Copied: images347.jpg -> /content/dataset/Train/Black Soil/476.jpg
# Copied: Copy of images435.jpg -> /content/dataset/Train/Black Soil/477.jpg
# Copied: Sample7.0.jpg -> /content/dataset/Train/Black Soil/478.jpg
# Copied: images363.jpg -> /content/dataset/Train/Black Soil/479.jpg
# Copied: Copy of images431(1).jpg -> /content/dataset/Train/Black Soil/480.jpg
# Copied: images271.jpg -> /content/dataset/Train/Black Soil/481.jpg
# Copied: images365.jpg -> /content/dataset/Train/Black Soil/482.jpg
# Copied: Sample7.90.jpg -> /content/dataset/Train/Black Soil/483.jpg
# Copied: images267.jpg -> /content/dataset/Train/Black Soil/484.jpg
# Copied: images350.jpg -> /content/dataset/Train/Black Soil/485.jpg
# Copied: images284.jpg -> /content/dataset/Train/Black Soil/486.jpg
# Copied: images371.jpg -> /content/dataset/Train/Black Soil/487.jpg
# Copied: images274.jpg -> /content/dataset/Train/Black Soil/488.jpg
# Copied: indian-soils-6.jpg -> /content/dataset/Train/Black Soil/489.jpg
# Copied: kalimitti2.jpg -> /content/dataset/Train/Black Soil/490.jpg
# Copied: images404.jpg -> /content/dataset/Train/Black Soil/491.jpg
# Copied: images433.jpg -> /content/dataset/Train/Black Soil/492.jpg
# Copied: images430.jpg -> /content/dataset/Train/Black Soil/493.jpg
# Copied: photo_2022-06-01_07-07-32.jpg -> /content/dataset/Train/Black Soil/494.jpg
# Copied: images434.jpg -> /content/dataset/Train/Black Soil/495.jpg
# Copied: Alluvial_17.png -> /content/dataset/Train/Alluvial soil/496.png
# Copied: Alluvial-soil-distribution-in-India-1.jpeg -> /content/dataset/Train/Alluvial soil/497.jpeg
# Copied: 1000_F_240425429_YL91trtDxXQl8L0OKP7zyngeSb63olAC.jpg -> /content/dataset/Train/Alluvial soil/498.jpg
# Copied: Alluvial_12.jpg -> /content/dataset/Train/Alluvial soil/499.jpg
# Copied: 01060602previewen-02d.jpg -> /content/dataset/Train/Alluvial soil/500.jpg
# Copied: Alluvial_12 - Copy.jpg -> /content/dataset/Train/Alluvial soil/501.jpg
# Copied: Alluvial_13.png -> /content/dataset/Train/Alluvial soil/502.png
# Copied: Alluvial_14.png -> /content/dataset/Train/Alluvial soil/503.png
# Copied: Alluvial_16.png -> /content/dataset/Train/Alluvial soil/504.png
# Copied: Alluvial_11.jpg -> /content/dataset/Train/Alluvial soil/505.jpg
# Copied: 01060602previewen-02b.jpg -> /content/dataset/Train/Alluvial soil/506.jpg
# Copied: Alluvial-soil-distribution-in-India.jpg -> /content/dataset/Train/Alluvial soil/507.jpg
# Copied: Alluvial-Soil..png -> /content/dataset/Train/Alluvial soil/508.png
# Copied: Alluvial_10.png -> /content/dataset/Train/Alluvial soil/509.png
# Copied: Alluvial_15.png -> /content/dataset/Train/Alluvial soil/510.png
# Copied: Alluvial_1.jpg -> /content/dataset/Train/Alluvial soil/511.jpg
# Copied: Alluvial_37.png -> /content/dataset/Train/Alluvial soil/512.png
# Copied: Alluvial_45.png -> /content/dataset/Train/Alluvial soil/513.png
# Copied: Alluvial_4.jpg -> /content/dataset/Train/Alluvial soil/514.jpg
# Copied: Alluvial_7.jpg -> /content/dataset/Train/Alluvial soil/515.jpg
# Copied: Alluvial_31.png -> /content/dataset/Train/Alluvial soil/516.png
# Copied: Alluvial_26.png -> /content/dataset/Train/Alluvial soil/517.png
# Copied: Alluvial_5.jpg -> /content/dataset/Train/Alluvial soil/518.jpg
# Copied: Alluvial_22.png -> /content/dataset/Train/Alluvial soil/519.png
# Copied: Alluvial_6 - Copy.jpg -> /content/dataset/Train/Alluvial soil/520.jpg
# Copied: Alluvial_24.png -> /content/dataset/Train/Alluvial soil/521.png
# Copied: Alluvial_38 - Copy.jpg -> /content/dataset/Train/Alluvial soil/522.jpg
# Copied: Alluvial_53.jpg -> /content/dataset/Train/Alluvial soil/523.jpg
# Copied: Alluvial_21.png -> /content/dataset/Train/Alluvial soil/524.png
# Copied: Alluvial_50.png -> /content/dataset/Train/Alluvial soil/525.png
# Copied: Alluvial_46.png -> /content/dataset/Train/Alluvial soil/526.png
# Copied: Alluvial_36.jpg -> /content/dataset/Train/Alluvial soil/527.jpg
# Copied: Alluvial_18.png -> /content/dataset/Train/Alluvial soil/528.png
# Copied: Alluvial_18 - Copy.png -> /content/dataset/Train/Alluvial soil/529.png
# Copied: Copy of 01060602previewen-02b.jpg -> /content/dataset/Train/Alluvial soil/530.jpg
# Copied: Alluvial_6.jpg -> /content/dataset/Train/Alluvial soil/531.jpg
# Copied: Alluvial_30.png -> /content/dataset/Train/Alluvial soil/532.png
# Copied: Alluvial_39.jpg -> /content/dataset/Train/Alluvial soil/533.jpg
# Copied: Alluvial_47.png -> /content/dataset/Train/Alluvial soil/534.png
# Copied: Alluvial_43.png -> /content/dataset/Train/Alluvial soil/535.png
# Copied: Alluvial_44.png -> /content/dataset/Train/Alluvial soil/536.png
# Copied: Alluvial_25.jpg -> /content/dataset/Train/Alluvial soil/537.jpg
# Copied: Copy of Alluvial-soil-distribution-in-India.jpg -> /content/dataset/Train/Alluvial soil/538.jpg
# Copied: Copy of Alluvial-Soil..png -> /content/dataset/Train/Alluvial soil/539.png
# Copied: Alluvial_35.jpg -> /content/dataset/Train/Alluvial soil/540.jpg
# Copied: Alluvial_29.jpg -> /content/dataset/Train/Alluvial soil/541.jpg
# Copied: Alluvial_34.png -> /content/dataset/Train/Alluvial soil/542.png
# Copied: Alluvial_38.jpg -> /content/dataset/Train/Alluvial soil/543.jpg
# Copied: Copy of 1000_F_240425429_YL91trtDxXQl8L0OKP7zyngeSb63olAC.jpg -> /content/dataset/Train/Alluvial soil/544.jpg
# Copied: Alluvial_23.jpg -> /content/dataset/Train/Alluvial soil/545.jpg
# Copied: Alluvial_8.png -> /content/dataset/Train/Alluvial soil/546.png
# Copied: Alluvial_20.jpg -> /content/dataset/Train/Alluvial soil/547.jpg
# Copied: Alluvial_28.jpg -> /content/dataset/Train/Alluvial soil/548.jpg
# Copied: Alluvial_33.png -> /content/dataset/Train/Alluvial soil/549.png
# Copied: Alluvial_35 - Copy.jpg -> /content/dataset/Train/Alluvial soil/550.jpg
# Copied: Alluvial_27.png -> /content/dataset/Train/Alluvial soil/551.png
# Copied: Copy of Alluvial-soil-distribution-in-India-1.jpeg -> /content/dataset/Train/Alluvial soil/552.jpeg
# Copied: Alluvial_3.png -> /content/dataset/Train/Alluvial soil/553.png
# Copied: Copy of IMG-20220531-WA0017.jpg -> /content/dataset/Train/Alluvial soil/554.jpg
# Copied: Copy of 01060602previewen-02d.jpg -> /content/dataset/Train/Alluvial soil/555.jpg
# Copied: Alluvial_2.png -> /content/dataset/Train/Alluvial soil/556.png
# Copied: Alluvial_42.jpg -> /content/dataset/Train/Alluvial soil/557.jpg
# Copied: Alluvial_41.jpg -> /content/dataset/Train/Alluvial soil/558.jpg
# Copied: Alluvial_19.png -> /content/dataset/Train/Alluvial soil/559.png
# Copied: Alluvial_9.jpg -> /content/dataset/Train/Alluvial soil/560.jpg
# Copied: Alluvial_48.png -> /content/dataset/Train/Alluvial soil/561.png
# Copied: Alluvial_32.jpg -> /content/dataset/Train/Alluvial soil/562.jpg
# Copied: Alluvial_40.jpg -> /content/dataset/Train/Alluvial soil/563.jpg
# Copied: Copy of IMG-20220531-WA0031.jpg -> /content/dataset/Train/Alluvial soil/564.jpg
# Copied: Copy of IMG-20220531-WA0022.jpg -> /content/dataset/Train/Alluvial soil/565.jpg
# Copied: Copy of IMG-20220531-WA0059.jpg -> /content/dataset/Train/Alluvial soil/566.jpg
# Copied: Copy of IMG-20220531-WA0061.jpg -> /content/dataset/Train/Alluvial soil/567.jpg
# Copied: Copy of IMG-20220531-WA0060.jpg -> /content/dataset/Train/Alluvial soil/568.jpg
# Copied: Copy of IMG-20220531-WA0050.jpg -> /content/dataset/Train/Alluvial soil/569.jpg
# Copied: Copy of IMG-20220531-WA0034.jpg -> /content/dataset/Train/Alluvial soil/570.jpg
# Copied: Copy of IMG-20220531-WA0041.jpg -> /content/dataset/Train/Alluvial soil/571.jpg
# Copied: Copy of IMG-20220531-WA0030.jpg -> /content/dataset/Train/Alluvial soil/572.jpg
# Copied: Copy of IMG-20220531-WA0056.jpg -> /content/dataset/Train/Alluvial soil/573.jpg
# Copied: Copy of IMG-20220531-WA0055.jpg -> /content/dataset/Train/Alluvial soil/574.jpg
# Copied: Copy of IMG-20220531-WA0052.jpg -> /content/dataset/Train/Alluvial soil/575.jpg
# Copied: Copy of IMG-20220531-WA0051.jpg -> /content/dataset/Train/Alluvial soil/576.jpg
# Copied: Copy of IMG-20220531-WA0021.jpg -> /content/dataset/Train/Alluvial soil/577.jpg
# Copied: Copy of IMG-20220531-WA0058.jpg -> /content/dataset/Train/Alluvial soil/578.jpg
# Copied: Copy of IMG-20220531-WA0054.jpg -> /content/dataset/Train/Alluvial soil/579.jpg
# Copied: Copy of IMG-20220531-WA0023.jpg -> /content/dataset/Train/Alluvial soil/580.jpg
# Copied: Copy of IMG-20220531-WA0035.jpg -> /content/dataset/Train/Alluvial soil/581.jpg
# Copied: Copy of IMG-20220531-WA0040.jpg -> /content/dataset/Train/Alluvial soil/582.jpg
# Copied: Copy of IMG-20220531-WA0044.jpg -> /content/dataset/Train/Alluvial soil/583.jpg
# Copied: Copy of IMG-20220531-WA0032.jpg -> /content/dataset/Train/Alluvial soil/584.jpg
# Copied: Copy of IMG-20220531-WA0047.jpg -> /content/dataset/Train/Alluvial soil/585.jpg
# Copied: Copy of IMG-20220531-WA0029.jpg -> /content/dataset/Train/Alluvial soil/586.jpg
# Copied: Copy of IMG-20220531-WA0065.jpg -> /content/dataset/Train/Alluvial soil/587.jpg
# Copied: Copy of IMG-20220531-WA0053.jpg -> /content/dataset/Train/Alluvial soil/588.jpg
# Copied: Copy of IMG-20220531-WA0024.jpg -> /content/dataset/Train/Alluvial soil/589.jpg
# Copied: Copy of IMG-20220531-WA0019.jpg -> /content/dataset/Train/Alluvial soil/590.jpg
# Copied: Copy of IMG-20220531-WA0066.jpg -> /content/dataset/Train/Alluvial soil/591.jpg
# Copied: Copy of IMG-20220531-WA0064.jpg -> /content/dataset/Train/Alluvial soil/592.jpg
# Copied: Copy of IMG-20220531-WA0036.jpg -> /content/dataset/Train/Alluvial soil/593.jpg
# Copied: Copy of IMG-20220531-WA0025.jpg -> /content/dataset/Train/Alluvial soil/594.jpg
# Copied: Copy of IMG-20220531-WA0069.jpg -> /content/dataset/Train/Alluvial soil/595.jpg
# Copied: Copy of IMG-20220531-WA0037.jpg -> /content/dataset/Train/Alluvial soil/596.jpg
# Copied: Copy of IMG-20220531-WA0048.jpg -> /content/dataset/Train/Alluvial soil/597.jpg
# Copied: Copy of IMG-20220531-WA0038.jpg -> /content/dataset/Train/Alluvial soil/598.jpg
# Copied: Copy of IMG-20220531-WA0033.jpg -> /content/dataset/Train/Alluvial soil/599.jpg
# Copied: Copy of IMG-20220531-WA0067.jpg -> /content/dataset/Train/Alluvial soil/600.jpg
# Copied: Copy of IMG-20220531-WA0028.jpg -> /content/dataset/Train/Alluvial soil/601.jpg
# Copied: Copy of IMG-20220531-WA0046.jpg -> /content/dataset/Train/Alluvial soil/602.jpg
# Copied: Copy of IMG-20220531-WA0027.jpg -> /content/dataset/Train/Alluvial soil/603.jpg
# Copied: Copy of IMG-20220531-WA0018.jpg -> /content/dataset/Train/Alluvial soil/604.jpg
# Copied: Copy of IMG-20220531-WA0070.jpg -> /content/dataset/Train/Alluvial soil/605.jpg
# Copied: Copy of IMG-20220531-WA0062.jpg -> /content/dataset/Train/Alluvial soil/606.jpg
# Copied: Copy of IMG-20220531-WA0043.jpg -> /content/dataset/Train/Alluvial soil/607.jpg
# Copied: Copy of IMG-20220531-WA0026.jpg -> /content/dataset/Train/Alluvial soil/608.jpg
# Copied: Copy of IMG-20220531-WA0068.jpg -> /content/dataset/Train/Alluvial soil/609.jpg
# Copied: Copy of IMG-20220531-WA0049.jpg -> /content/dataset/Train/Alluvial soil/610.jpg
# Copied: Copy of IMG-20220531-WA0039.jpg -> /content/dataset/Train/Alluvial soil/611.jpg
# Copied: Copy of IMG-20220531-WA0063.jpg -> /content/dataset/Train/Alluvial soil/612.jpg
# Copied: Copy of IMG-20220531-WA0057.jpg -> /content/dataset/Train/Alluvial soil/613.jpg
# Copied: Copy of IMG-20220531-WA0020.jpg -> /content/dataset/Train/Alluvial soil/614.jpg
# Copied: Copy of IMG-20220531-WA0045.jpg -> /content/dataset/Train/Alluvial soil/615.jpg
# Copied: Copy of Sample11.0.jpg -> /content/dataset/Train/Alluvial soil/616.jpg
# Copied: Copy of Sample10.30.jpg -> /content/dataset/Train/Alluvial soil/617.jpg
# Copied: Copy of IMG-20220531-WA0088.jpg -> /content/dataset/Train/Alluvial soil/618.jpg
# Copied: Copy of IMG-20220531-WA0091.jpg -> /content/dataset/Train/Alluvial soil/619.jpg
# Copied: Copy of IMG-20220531-WA0071.jpg -> /content/dataset/Train/Alluvial soil/620.jpg
# Copied: Copy of alluvial-diamond-layers-mining-site-western-cape-south-africa-G8CR87.jpg -> /content/dataset/Train/Alluvial soil/621.jpg
# Copied: Copy of Sample10.60.jpg -> /content/dataset/Train/Alluvial soil/622.jpg
# Copied: Copy of Sample10.90.jpg -> /content/dataset/Train/Alluvial soil/623.jpg
# Copied: Copy of Sample9.90.jpg -> /content/dataset/Train/Alluvial soil/624.jpg
# Copied: Copy of Sample9.30.jpg -> /content/dataset/Train/Alluvial soil/625.jpg
# Copied: Copy of IMG-20220531-WA0089.jpg -> /content/dataset/Train/Alluvial soil/626.jpg
# Copied: Copy of alluvial-soil-1kg-green-era-original-imag4r54hhybzhqc.jpeg -> /content/dataset/Train/Alluvial soil/627.jpeg
# Copied: Copy of IMG-20220531-WA0077.jpg -> /content/dataset/Train/Alluvial soil/628.jpg
# Copied: Copy of IMG-20220531-WA0075.jpg -> /content/dataset/Train/Alluvial soil/629.jpg
# Copied: Copy of IMG-20220531-WA0081.jpg -> /content/dataset/Train/Alluvial soil/630.jpg
# Copied: Copy of Sample13.60.jpg -> /content/dataset/Train/Alluvial soil/631.jpg
# Copied: Copy of IMG-20220531-WA0080.jpg -> /content/dataset/Train/Alluvial soil/632.jpg
# Copied: Copy of IMG-20220531-WA0082.jpg -> /content/dataset/Train/Alluvial soil/633.jpg
# Copied: Copy of Sample9.150.jpg -> /content/dataset/Train/Alluvial soil/634.jpg
# Copied: Copy of Photograph-showing-the-presence-of-alluvial-soil-along-stream-course-dry-near-Patlodha_Q640.jpg -> /content/dataset/Train/Alluvial soil/635.jpg
# Copied: Copy of Sample11.180.jpg -> /content/dataset/Train/Alluvial soil/636.jpg
# Copied: Copy of IMG-20220531-WA0086.jpg -> /content/dataset/Train/Alluvial soil/637.jpg
# Copied: Copy of Sample11.60.jpg -> /content/dataset/Train/Alluvial soil/638.jpg
# Copied: Copy of IMG-20220531-WA0074.jpg -> /content/dataset/Train/Alluvial soil/639.jpg
# Copied: Copy of IMG-20220531-WA0079.jpg -> /content/dataset/Train/Alluvial soil/640.jpg
# Copied: Copy of Sample9.180.jpg -> /content/dataset/Train/Alluvial soil/641.jpg
# Copied: Copy of Sample9.0.jpg -> /content/dataset/Train/Alluvial soil/642.jpg
# Copied: Copy of IMG-20220531-WA0078.jpg -> /content/dataset/Train/Alluvial soil/643.jpg
# Copied: Copy of Sample10.150.jpg -> /content/dataset/Train/Alluvial soil/644.jpg
# Copied: Copy of IMG-20220531-WA0090.jpg -> /content/dataset/Train/Alluvial soil/645.jpg
# Copied: Copy of IMG-20220531-WA0087.jpg -> /content/dataset/Train/Alluvial soil/646.jpg
# ...
# Copied: Clay_3.jpg -> /content/dataset/Test/Clay soil/1342.jpg
# Copied: Copy of 91714675-background-of-red-clay-the-real-desert-soil.png -> /content/dataset/Test/Clay soil/1343.png
# Copied: Copy of 94530057-red-clay-soil-on-nature-as-a-background-.png -> /content/dataset/Test/Clay soil/1344.png
# Copied: Clay_1.jpg -> /content/dataset/Test/Clay soil/1345.jpg
# Copied: Clay_15.jpg -> /content/dataset/Test/Clay soil/1346.jpg
# Copied: Clay_16.jpg -> /content/dataset/Test/Clay soil/1347.jpg
# Copied: Clay_4.jpg -> /content/dataset/Test/Clay soil/1348.jpg
# Copied: Clay_10.jpg -> /content/dataset/Test/Clay soil/1349.jpg
# Copied: Clay_17.jpg -> /content/dataset/Test/Clay soil/1350.jpg
# Copied: Clay_44.jpg -> /content/dataset/Test/Clay soil/1351.jpg
# Copied: Clay_9.jpg -> /content/dataset/Test/Clay soil/1352.jpg
# Copied: Clay_45.jpg -> /content/dataset/Test/Clay soil/1353.jpg
# Copied: Clay_8.jpg -> /content/dataset/Test/Clay soil/1354.jpg
# Copied: Clay_14.jpg -> /content/dataset/Test/Clay soil/1355.jpg
# Copied: Clay_13.jpg -> /content/dataset/Test/Clay soil/1356.jpg
# Copied: 94530057-red-clay-soil-on-nature-as-a-background-.png -> /content/dataset/Test/Clay soil/1357.png
# Copied: Clay_11.jpg -> /content/dataset/Test/Clay soil/1358.jpg
# Copied: Copy of images407(1).jpg -> /content/dataset/Test/Clay soil/1359.jpg
# Copied: Copy of images76(1).jpg -> /content/dataset/Test/Clay soil/1360.jpg
# Copied: Copy of red-clay-soil-closeup-red-clay-soil-closeup-as-natural-background-989216052.jpg -> /content/dataset/Test/Clay soil/1361.jpg
# Copied: Copy of man-working-shovel-clay-260nw-639044377(1).png -> /content/dataset/Test/Clay soil/1362.png
# Copied: Copy of clay-soil2.jpg -> /content/dataset/Test/Clay soil/1363.jpg
# Copied: Copy of cracked-clay-soil-12498989.jpg -> /content/dataset/Test/Clay soil/1364.jpg
# Copied: Copy of clay-soil-cropped.jpg -> /content/dataset/Test/Clay soil/1365.jpg
# Copied: Copy of images34.jpg -> /content/dataset/Test/Clay soil/1366.jpg
# Copied: Copy of Sample1.0.jpg -> /content/dataset/Test/Clay soil/1367.jpg
# Copied: Copy of plants-clay-soil-intro.jpg -> /content/dataset/Test/Clay soil/1368.jpg
# Copied: Copy of images43.jpg -> /content/dataset/Test/Clay soil/1369.jpg
# Copied: image23 (2).jpeg -> /content/dataset/Test/Clay soil/1370.jpeg
# Copied: Copy of clay.jpg -> /content/dataset/Test/Clay soil/1371.jpg
# Copied: Copy of images407.jpg -> /content/dataset/Test/Clay soil/1372.jpg
# Copied: Copy of images76.jpg -> /content/dataset/Test/Clay soil/1373.jpg
# Copied: clay-soil-cut-red-color-clay-clay-soil-cut-red-color-clay-184254602.jpg -> /content/dataset/Test/Clay soil/1374.jpg
# Copied: Sample1.120.jpg -> /content/dataset/Test/Clay soil/1375.jpg
# Copied: Copy of Clayey-Soil-img.jpg -> /content/dataset/Test/Clay soil/1376.jpg
# Copied: Copy of Clay_Soil.jpg -> /content/dataset/Test/Clay soil/1377.jpg
# Copied: Copy of clay-soil-close-up-brown-179039817.jpg -> /content/dataset/Test/Clay soil/1378.jpg
# Copied: Copy of clay-260nw-614429543.png -> /content/dataset/Test/Clay soil/1379.png
# Copied: images72.jpg -> /content/dataset/Test/Clay soil/1380.jpg
# Copied: Copy of man-working-shovel-clay-260nw-639044377.png -> /content/dataset/Test/Clay soil/1381.png
# Copied: Copy of Sample1.120.jpg -> /content/dataset/Test/Clay soil/1382.jpg
# Copied: Copy of Sample1.60.jpg -> /content/dataset/Test/Clay soil/1383.jpg
# Copied: Copy of images43(1).jpg -> /content/dataset/Test/Clay soil/1384.jpg
# Copied: Copy of images72.jpg -> /content/dataset/Test/Clay soil/1385.jpg
# Copied: Copy of Sample1.30.jpg -> /content/dataset/Test/Clay soil/1386.jpg
# Copied: red-clay-soil-closeup-red-clay-soil-closeup-as-natural-background-98921605.jpg -> /content/dataset/Test/Clay soil/1387.jpg
# Copied: Copy of Clay-Soil(2).jpg -> /content/dataset/Test/Clay soil/1388.jpg
# Copied: Copy of images72(1).jpg -> /content/dataset/Test/Clay soil/1389.jpg
# Copied: clay-soil-field.jpg -> /content/dataset/Test/Clay soil/1390.jpg
# Copied: clay-soil-close-up-brown-179039817.jpg -> /content/dataset/Test/Clay soil/1391.jpg
# Copied: Copy of clay-soil.jpg -> /content/dataset/Test/Clay soil/1392.jpg
# Copied: Copy of red-clay-soil-closeup-red-clay-soil-closeup-as-natural-background-98921605.jpg -> /content/dataset/Test/Clay soil/1393.jpg
# Copied: Copy of Sample1.90.jpg -> /content/dataset/Test/Clay soil/1394.jpg
# Copied: Copy of cracked-clay-soil-12498989(1).jpg -> /content/dataset/Test/Clay soil/1395.jpg
# Copied: Copy of Sample1.150.jpg -> /content/dataset/Test/Clay soil/1396.jpg
# Copied: Copy of image17 (2).jpeg -> /content/dataset/Test/Alluvial soil/1397.jpeg
# Copied: Alluvial_25.jpg -> /content/dataset/Test/Alluvial soil/1398.jpg
# Copied: Copy of oil-a-real-close-up-of-a-part-of-the-earth-s-crust-ordinary-plain-1922365577.jpg -> /content/dataset/Test/Alluvial soil/1399.jpg
# Copied: Copy of image (2).jpeg -> /content/dataset/Test/Alluvial soil/1400.jpeg
# Copied: Alluvial_48.png -> /content/dataset/Test/Alluvial soil/1401.png
# Copied: Copy of desktop_137249cc-6732-40b3-94e1-1381ad82c07f.jpg -> /content/dataset/Test/Alluvial soil/1402.jpg
# Copied: Sample13.150.jpg -> /content/dataset/Test/Alluvial soil/1403.jpg
# Copied: Alluvial_6 - Copy.jpg -> /content/dataset/Test/Alluvial soil/1404.jpg
# Copied: Alluvial_53.jpg -> /content/dataset/Test/Alluvial soil/1405.jpg
# Copied: Copy of image6 (2).jpeg -> /content/dataset/Test/Alluvial soil/1406.jpeg
# Copied: Alluvial_9.jpg -> /content/dataset/Test/Alluvial soil/1407.jpg
# Copied: Alluvial_8.png -> /content/dataset/Test/Alluvial soil/1408.png
# Copied: Alluvial_1.jpg -> /content/dataset/Test/Alluvial soil/1409.jpg
# Copied: Alluvial_23.jpg -> /content/dataset/Test/Alluvial soil/1410.jpg
# Copied: Alluvial_11.jpg -> /content/dataset/Test/Alluvial soil/1411.jpg
# Copied: Alluvial_27.png -> /content/dataset/Test/Alluvial soil/1412.png
# Copied: Copy of image16 (3).jpeg -> /content/dataset/Test/Alluvial soil/1413.jpeg
# Copied: Alluvial_26.png -> /content/dataset/Test/Alluvial soil/1414.png
# Copied: Copy of close-up-of-alluvial-soil-as-a-texturebackground-JCB3RY.jpg -> /content/dataset/Test/Alluvial soil/1415.jpg
# Copied: Alluvial_28.jpg -> /content/dataset/Test/Alluvial soil/1416.jpg
# Copied: Alluvial_6.jpg -> /content/dataset/Test/Alluvial soil/1417.jpg
# Copied: Sample13.180.jpg -> /content/dataset/Test/Alluvial soil/1418.jpg
# Copied: Alluvial_22.png -> /content/dataset/Test/Alluvial soil/1419.png
# Copied: Alluvial_10.png -> /content/dataset/Test/Alluvial soil/1420.png
# Copied: Sample13.120.jpg -> /content/dataset/Test/Alluvial soil/1421.jpg
# Copied: Alluvial_29.jpg -> /content/dataset/Test/Alluvial soil/1422.jpg
# Copied: Copy of IMG-20220531-WA0075.jpg -> /content/dataset/Test/Alluvial soil/1423.jpg
# Copied: Alluvial_24.png -> /content/dataset/Test/Alluvial soil/1424.png
# Copied: Alluvial_4.jpg -> /content/dataset/Test/Alluvial soil/1425.jpg
# Copied: IMG-20220531-WA0023.jpg -> /content/dataset/Test/Alluvial soil/1426.jpg
# Copied: Alluvial_3.jpg -> /content/dataset/Test/Alluvial soil/1427.jpg
# Copied: Copy of alluvial-soils-ricker-2primefarmland-1200x675-1.jpg -> /content/dataset/Test/Alluvial soil/1428.jpg
# Copied: Alluvial_30.png -> /content/dataset/Test/Alluvial soil/1429.png
# Copied: Alluvial_7.jpg -> /content/dataset/Test/Alluvial soil/1430.jpg
# Copied: Alluvial_50.png -> /content/dataset/Test/Alluvial soil/1431.png
# Copied: Sample11.90.jpg -> /content/dataset/Test/Alluvial soil/1432.jpg
# Copied: photo_2022-06-01_07-08-18.jpg -> /content/dataset/Test/Alluvial soil/1433.jpg
# Copied: images86.jpg -> /content/dataset/Test/Alluvial soil/1434.jpg
# Copied: image17 (2).jpeg -> /content/dataset/Test/Alluvial soil/1435.jpeg
# Copied: unnamed-1-2.jpg -> /content/dataset/Test/Alluvial soil/1436.jpg
# Copied: image7 (2).jpeg -> /content/dataset/Test/Alluvial soil/1437.jpeg
# Copied: image3 (2).jpeg -> /content/dataset/Test/Alluvial soil/1438.jpeg
# Copied: photo_2022-06-01_07-08-40.jpg -> /content/dataset/Test/Alluvial soil/1439.jpg
# Copied: photo_2022-06-01_07-08-36.jpg -> /content/dataset/Test/Alluvial soil/1440.jpg
# Copied: image6 (2).jpeg -> /content/dataset/Test/Alluvial soil/1441.jpeg
# Copied: photo_2022-06-01_07-09-46.jpg -> /content/dataset/Test/Alluvial soil/1442.jpg
# Copied: image16 (2).jpeg -> /content/dataset/Test/Alluvial soil/1443.jpeg
# Copied: images81.jpg -> /content/dataset/Test/Alluvial soil/1444.jpg
# Copied: image15 (2).jpeg -> /content/dataset/Test/Alluvial soil/1445.jpeg
# Copied: Sample9.90.jpg -> /content/dataset/Test/Alluvial soil/1446.jpg
# Copied: 1.jpg -> /content/dataset/Test/Alluvial soil/1447.jpg
# Copied: 2.jpg -> /content/dataset/Test/Alluvial soil/1448.jpg
# Copied: 3.jpg -> /content/dataset/Test/Alluvial soil/1449.jpg
# Copied: Copy of 95424d278d0b71fa4b398f406303a4a9.jpg -> /content/dataset/Test/Red soil/1450.jpg
# Copied: Copy of download.jpg -> /content/dataset/Test/Red soil/1451.jpg
# Copied: Copy of 2560px-A_red_soil_crop_field.png -> /content/dataset/Test/Red soil/1452.png
# Copied: Copy of 61050549-red-soil-texture-background.png -> /content/dataset/Test/Red soil/1453.png
# Copied: Copy of annamalai-red-soil-suppliers-kotturpuram-chennai-red-soil-dealers-ey0ylh5r3e.jpg -> /content/dataset/Test/Red soil/1454.jpg
# Copied: Copy of download (1).jpg -> /content/dataset/Test/Red soil/1455.jpg
# Copied: Copy of 1000_F_233167094_JhQz9xvHtlN5UyT3zt748JiJolOSid7s.jpg -> /content/dataset/Test/Red soil/1456.jpg
# Copied: Copy of download (2).jpg -> /content/dataset/Test/Red soil/1457.jpg
# Copied: Red_19.jpg -> /content/dataset/Test/Red soil/1458.jpg
# Copied: Copy of image.jpeg -> /content/dataset/Test/Red soil/1459.jpeg
# Copied: Red_11.jpg -> /content/dataset/Test/Red soil/1460.jpg
# Copied: Copy of image14.jpeg -> /content/dataset/Test/Red soil/1461.jpeg
# Copied: Red_14.jpg -> /content/dataset/Test/Red soil/1462.jpg
# Copied: Copy of image23.jpeg -> /content/dataset/Test/Red soil/1463.jpeg
# Copied: Copy of image17.jpeg -> /content/dataset/Test/Red soil/1464.jpeg
# Copied: Red_10.jpg -> /content/dataset/Test/Red soil/1465.jpg
# Copied: Copy of images102.jpg -> /content/dataset/Test/Red soil/1466.jpg
# Copied: Copy of image2.jpeg -> /content/dataset/Test/Red soil/1467.jpeg
# Copied: Copy of images104.jpg -> /content/dataset/Test/Red soil/1468.jpg
# Copied: Copy of image12.jpeg -> /content/dataset/Test/Red soil/1469.jpeg
# Copied: Copy of images95.jpg -> /content/dataset/Test/Red soil/1470.jpg
# Copied: Copy of image-red-soil-texture-260nw-243951718.png -> /content/dataset/Test/Red soil/1471.png
# Copied: Red_1.jpg -> /content/dataset/Test/Red soil/1472.jpg
# Copied: Red-soil-essay.jpg -> /content/dataset/Test/Red soil/1473.jpg
# Copied: Red_13.jpg -> /content/dataset/Test/Red soil/1474.jpg
# Copied: Copy of image24.jpeg -> /content/dataset/Test/Red soil/1475.jpeg
# Copied: Copy of images135.jpg -> /content/dataset/Test/Red soil/1476.jpg
# Copied: Copy of images (1).jpg -> /content/dataset/Test/Red soil/1477.jpg
# Copied: Copy of images122.jpg -> /content/dataset/Test/Red soil/1478.jpg
# Copied: Red_16.jpg -> /content/dataset/Test/Red soil/1479.jpg
# Copied: Copy of image25.jpeg -> /content/dataset/Test/Red soil/1480.jpeg
# Copied: Copy of image20.jpeg -> /content/dataset/Test/Red soil/1481.jpeg
# Copied: Copy of images113.jpg -> /content/dataset/Test/Red soil/1482.jpg
# Copied: Copy of images125.jpg -> /content/dataset/Test/Red soil/1483.jpg
# Copied: Copy of images96.jpg -> /content/dataset/Test/Red soil/1484.jpg
# Copied: Copy of images117.jpg -> /content/dataset/Test/Red soil/1485.jpg
# Copied: Copy of images120.jpg -> /content/dataset/Test/Red soil/1486.jpg
# Copied: Copy of image30.jpeg -> /content/dataset/Test/Red soil/1487.jpeg
# Copied: Copy of image26.jpeg -> /content/dataset/Test/Red soil/1488.jpeg
# Copied: Copy of images131.jpg -> /content/dataset/Test/Red soil/1489.jpg
# Copied: Copy of images105.jpg -> /content/dataset/Test/Red soil/1490.jpg
# Copied: Red_2.jpg -> /content/dataset/Test/Red soil/1491.jpg
# Copied: Copy of images43.jpg -> /content/dataset/Test/Red soil/1492.jpg
# Copied: Copy of image31.jpeg -> /content/dataset/Test/Red soil/1493.jpeg
# Copied: Red_18.jpg -> /content/dataset/Test/Red soil/1494.jpg
# Copied: Red_12.jpg -> /content/dataset/Test/Red soil/1495.jpg
# Copied: Copy of images119.jpg -> /content/dataset/Test/Red soil/1496.jpg
# Copied: Copy of image15.jpeg -> /content/dataset/Test/Red soil/1497.jpeg
# Copied: Red_17.jpg -> /content/dataset/Test/Red soil/1498.jpg
# Copied: Copy of images.jpg -> /content/dataset/Test/Red soil/1499.jpg
# Copied: Red_21.jpg -> /content/dataset/Test/Red soil/1500.jpg
# Copied: Copy of image5.jpeg -> /content/dataset/Test/Red soil/1501.jpeg
# Copied: Copy of image19.jpeg -> /content/dataset/Test/Red soil/1502.jpeg
# Copied: Copy of image3.jpeg -> /content/dataset/Test/Red soil/1503.jpeg
# Copied: Red_20.jpg -> /content/dataset/Test/Red soil/1504.jpg
# Copied: Nc-red-clay-soil-2.jpg -> /content/dataset/Test/Red soil/1505.jpg
# Copied: Copy of images141.jpg -> /content/dataset/Test/Red soil/1506.jpg
# Copied: Copy of image16.jpeg -> /content/dataset/Test/Red soil/1507.jpeg
# Copied: Copy of image8.jpeg -> /content/dataset/Test/Red soil/1508.jpeg
# Copied: Red_15.jpg -> /content/dataset/Test/Red soil/1509.jpg
# Copied: Red_22.jpg -> /content/dataset/Test/Red soil/1510.jpg
# Copied: Red_30.jpg -> /content/dataset/Test/Red soil/1511.jpg
# Copied: Red_39.jpg -> /content/dataset/Test/Red soil/1512.jpg
# Copied: images202.jpg -> /content/dataset/Test/Red soil/1513.jpg
# Copied: images195.jpg -> /content/dataset/Test/Red soil/1514.jpg
# Copied: Red_7.jpg -> /content/dataset/Test/Red soil/1515.jpg
# Copied: Red_27.jpg -> /content/dataset/Test/Red soil/1516.jpg
# Copied: Red_4.jpg -> /content/dataset/Test/Red soil/1517.jpg
# Copied: Red_8.jpg -> /content/dataset/Test/Red soil/1518.jpg
# Copied: Red_46.jpg -> /content/dataset/Test/Red soil/1519.jpg
# Copied: Red_43.jpg -> /content/dataset/Test/Red soil/1520.jpg
# Copied: Red_5.jpg -> /content/dataset/Test/Red soil/1521.jpg
# Copied: red20clay-700x700.jpg -> /content/dataset/Test/Red soil/1522.jpg
# Copied: Red_40.jpg -> /content/dataset/Test/Red soil/1523.jpg
# Copied: Red_6.jpg -> /content/dataset/Test/Red soil/1524.jpg
# Copied: Red_44.jpg -> /content/dataset/Test/Red soil/1525.jpg
# Copied: Red_28.jpg -> /content/dataset/Test/Red soil/1526.jpg
# Copied: Red_37.jpg -> /content/dataset/Test/Red soil/1527.jpg
# Copied: Red_35.jpg -> /content/dataset/Test/Red soil/1528.jpg
# Copied: Red_42.jpg -> /content/dataset/Test/Red soil/1529.jpg
# Copied: red3.jpg -> /content/dataset/Test/Red soil/1530.jpg
# Copied: images189.jpg -> /content/dataset/Test/Red soil/1531.jpg
# Copied: red-soil-1.png -> /content/dataset/Test/Red soil/1532.png
# Copied: red-soil-500x5003.png -> /content/dataset/Test/Red soil/1533.png
# Copied: images177.jpg -> /content/dataset/Test/Red soil/1534.jpg
# Copied: images188.jpg -> /content/dataset/Test/Red soil/1535.jpg
# Copied: Sample6.0.jpg -> /content/dataset/Test/Red soil/1536.jpg
# Copied: Red_9.jpg -> /content/dataset/Test/Red soil/1537.jpg
# Copied: Red_23.jpg -> /content/dataset/Test/Red soil/1538.jpg
# Copied: Red_36.jpg -> /content/dataset/Test/Red soil/1539.jpg
# Copied: images191.jpg -> /content/dataset/Test/Red soil/1540.jpg
# Copied: Red_41.jpg -> /content/dataset/Test/Red soil/1541.jpg
# Copied: Red_31.jpg -> /content/dataset/Test/Red soil/1542.jpg
# Copied: Red_32.jpg -> /content/dataset/Test/Red soil/1543.jpg
# Copied: Sample6.60.jpg -> /content/dataset/Test/Red soil/1544.jpg
# Copied: Red_24.jpg -> /content/dataset/Test/Red soil/1545.jpg
# Copied: Red_45.jpg -> /content/dataset/Test/Red soil/1546.jpg
# Copied: red-ground-texture-260nw-1079913677.png -> /content/dataset/Test/Red soil/1547.png
# Copied: Red_38.jpg -> /content/dataset/Test/Red soil/1548.jpg
# Copied: images183.jpg -> /content/dataset/Test/Red soil/1549.jpg
# Copied: red-soil-500x5002.jpg -> /content/dataset/Test/Red soil/1550.jpg
# Copied: Sample6.30.jpg -> /content/dataset/Test/Red soil/1551.jpg
# Copied: red-soil-background-6402446.jpg -> /content/dataset/Test/Red soil/1552.jpg
# Copied: Red_29.jpg -> /content/dataset/Test/Red soil/1553.jpg
# Copied: Red_3.jpg -> /content/dataset/Test/Red soil/1554.jpg
# Copied: images192.jpg -> /content/dataset/Test/Red soil/1555.jpg
# ✅ New dataset saved in: /content/dataset

# %%
# Load and sort training folder classes
soils_train = sorted(os.listdir("/content/dataset/Train"))
print("Train Classes:", soils_train)

# Load and sort validation folder classes
soils_validations = sorted(os.listdir("/content/dataset/Test"))
print("Validation Classes:", soils_validations)
# Out:
# Train Classes: ['Alluvial soil', 'Black Soil', 'Clay soil', 'Red soil']
# Validation Classes: ['Alluvial soil', 'Black Soil', 'Clay soil', 'Red soil']

# %%
soils_train_images = {}
for soil in soils_train:
    soils_train_images[soil] = os.listdir(f"/content/dataset/Train/{soil}")

# %%
for soil in soils_train_images:
    print(f"Dataset contains {len(soils_train_images[soil])} images of {soil}")
# Out:
# Dataset contains 523 images of Alluvial soil
# Dataset contains 228 images of Black Soil
# Dataset contains 197 images of Clay soil
# Dataset contains 267 images of Red soil

# %%
# Define paths البيانات لصور التربة
train_data_dir = '/content/dataset/Train'
test_data_dir = '/content/dataset/Test'

# Function to load images
def load_images_from_folder(folder):
    images = []  # مصفوفة للصور
    labels = []  # مصفوفة للأسماء

    for label in os.listdir(folder):
        label_path = os.path.join(folder, label)
        if not os.path.isdir(label_path):  # تأكد أنه مجلد وليس ملف
            continue

        for image_name in os.listdir(label_path):
            image_path = os.path.join(label_path, image_name)
            image = cv2.imread(image_path)
            if image is None:  # تحقق من أن الصورة لم تفشل في التحميل
                print(f"Warning: Couldn't read image {image_path}")
                continue

            image = cv2.resize(image, (64, 64))  # تصغير الصور إلى 64x64
            images.append(image)
            labels.append(label)

    return np.array(images), np.array(labels)

# تحميل البيانات
X_train, y_train = load_images_from_folder(train_data_dir)
X_test, y_test = load_images_from_folder(test_data_dir)

# تحويل التصنيفات إلى أرقام
label_to_index = {label: idx for idx, label in enumerate(np.unique(y_train))}
index_to_label = {idx: label for label, idx in label_to_index.items()}

y_train = np.array([label_to_index[label] for label in y_train])
y_test = np.array([label_to_index[label] for label in y_test])

# تحويل التصنيفات إلى One-Hot Encoding
#have 4 classes {'Alluvial soil': 0, 'Black Soil': 1, 'Clay soil': 2, 'Red soil': 3}
y_train = to_categorical(y_train, num_classes=len(label_to_index))
y_test = to_categorical(y_test, num_classes=len(label_to_index))

# تطبيع الصور
X_train = X_train.astype('float32') / 255.0
X_test = X_test.astype('float32') / 255.0

# بناء نموذج CNN
model_cnn = Sequential([
    Conv2D(32, (3, 3), activation='relu', input_shape=(64, 64, 3)),
    MaxPooling2D(pool_size=(2, 2)),
    Conv2D(64, (3, 3), activation='relu'),
    MaxPooling2D(pool_size=(2, 2)),
    Flatten(),
    Dense(128, activation='relu'),
    Dropout(0.5),
    Dense(len(label_to_index), activation='softmax')  # سوفت ماكس لتصنيف متعدد
])

# تجميع النموذج
model_cnn.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# تدريب النموذج
model_cnn.fit(X_train, y_train, epochs=10, batch_size=32, validation_data=(X_test, y_test))  #
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/10
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 58ms/step - accuracy: 0.5185 - loss: 1.1690 - val_accuracy: 0.7500 - val_loss: 0.6795
# Epoch 2/10
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.7820 - loss: 0.5900 - val_accuracy: 0.8441 - val_loss: 0.4523
# Epoch 3/10
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8624 - loss: 0.3883 - val_accuracy: 0.8765 - val_loss: 0.3104
# Epoch 4/10
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.8691 - loss: 0.3317 - val_accuracy: 0.8882 - val_loss: 0.3041
# Epoch 5/10
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8911 - loss: 0.2681 - val_accuracy: 0.9529 - val_loss: 0.1867
# Epoch 6/10
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9204 - loss: 0.2475 - val_accuracy: 0.9529 - val_loss: 0.1759
# Epoch 7/10
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9313 - loss: 0.1997 - val_accuracy: 0.9206 - val_loss: 0.2233
# Epoch 8/10
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9336 - loss: 0.2058 - val_accuracy: 0.9765 - val_loss: 0.1025
# Epoch 9/10
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9664 - loss: 0.1173 - val_accuracy: 0.9647 - val_loss: 0.0975
# Epoch 10/10
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9643 - loss: 0.1091 - val_accuracy: 0.9676 - val_loss: 0.0926

# %%
# Save the model as h5
model_cnn.save("soil_classifier.h5")

# # Convert to TFLite
converter = tf.lite.TFLiteConverter.from_keras_model(model_cnn)
tflite_model = converter.convert()

# Save the converted model
with open("soil_classifierls.tflite", "wb") as f:
    f.write(tflite_model)

print("Model converted successfully!")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Saved artifact at '/tmp/tmp9skwx3sm'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 64, 64, 3), dtype=tf.float32, name='keras_tensor_170')
# Output Type:
#   TensorSpec(shape=(None, 4), dtype=tf.float32, name=None)
# Captures:
#   137421708367184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137421708363152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137421708364304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137421708364496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137421708363344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137421708365264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137421708365648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137421708376976: TensorSpec(shape=(), dtype=tf.resource, name=None)
# Model converted successfully!

# %%
print(label_to_index)
# Out:
# {'Alluvial soil': 0, 'Black Soil': 1, 'Clay soil': 2, 'Red soil': 3}
